# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sea
import tensorflow as tf
import random
import gc

import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet152V2
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, ReLU, BatchNormalization, Dropout
from tensorflow.keras.initializers import HeNormal, Ones, Constant
from tensorflow.keras.optimizers import AdamW
from tensorflow.keras.optimizers.schedules import CosineDecayRestarts 
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

from sklearn.metrics import confusion_matrix
import warnings
warnings.filterwarnings("ignore")

# %%
SEED = 3126  
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
WIDTH, HEIGHT = 224, 224
BATCH_SIZE = 32
EPOCHS = 25
DIR = "/kaggle/input/finalized-astrovision-data/denoised (1)/denoised"

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    width_shift_range=0.125,
    height_shift_range=0.125,
    shear_range=0.15,
    zoom_range=0.15,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='nearest',
    validation_split=0.25
)
train_generator = train_datagen.flow_from_directory(
    DIR,
    target_size=(WIDTH, HEIGHT),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training',
    seed=SEED,
    shuffle=True
)

validation_generator = train_datagen.flow_from_directory(
    DIR,
    target_size=(WIDTH, HEIGHT),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation',
    seed=SEED,
    shuffle=False
)
# Out:
# Found 4607 images belonging to 4 classes.
# Found 1534 images belonging to 4 classes.

# %%
def make_dense_layer(input_size, dropout_rate=0.0, input_shape=None):
    layers = []
    if input_shape:
        layers.append(Dense(input_size,
                            use_bias=False, 
                            input_shape=input_shape,
                            kernel_initializer=HeNormal()
                            ))
    else:
        layers.append(Dense(input_size, use_bias=False, kernel_initializer=HeNormal()))
    layers.extend([BatchNormalization(gamma_initializer=Ones(), beta_initializer=Constant(0.1)),
                  ReLU()])
    if dropout_rate > 0:
        layers.append(Dropout(dropout_rate))
    return Sequential(layers)

# %%
def build_model():
    base_model = ResNet152V2(weights="imagenet", include_top=False,
                             input_shape=(WIDTH, HEIGHT, 3))
    base_model.trainable = False
    x = base_model.output
    x = GlobalAveragePooling2D()(x)

    fc_layers = Sequential([
        make_dense_layer(1024, input_shape=(x.shape[-1],), dropout_rate=.2),
        make_dense_layer(512, dropout_rate=.2),
        make_dense_layer(8)
    ])
    x = fc_layers(x)
    predictions = Dense(train_generator.num_classes,
                        activation='softmax',
                        kernel_initializer=HeNormal())(x)

    model = Model(inputs=base_model.input, outputs=predictions)
    model.compile(optimizer=AdamW(learning_rate=.0001,
                                  weight_decay=.00001
                                 ),
                 loss='categorical_crossentropy',
                 metrics=['accuracy'])   
    return model

# %%
model = build_model()
model.load_weights("/kaggle/input/resnet152v2-model/best_weights.weights.h5")

best_path = "/kaggle/working/best_weights.weights.h5"

checkpoint_callback = ModelCheckpoint(
    filepath=best_path,  
    monitor='val_loss',    
    save_best_only=True,       
    save_weights_only=True,    
    mode='min',                
    verbose=1,
    initial_value_threshold=.34
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234545216/234545216 ━━━━━━━━━━━━━━━━━━━━ 6s 0us/step

# %%
class ClearMemory(Callback):
    def on_epoch_end(self, epoch, logs=None):
        K.clear_session()  
        gc.collect()

# %%
history = model.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=validation_generator,
    callbacks=[checkpoint_callback, ClearMemory()]
)

model.load_weights(best_path)
initial_test_loss, initial_test_acc = model.evaluate(validation_generator, 
                                                     steps=validation_generator.samples // BATCH_SIZE)

print(f"Test Accuracy Before Fine-tuning: {initial_test_acc*100:.2f}%")
# Out:
# Epoch 1/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8671 - loss: 0.3185
# Epoch 1: val_loss did not improve from 0.34000
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1362s 9s/step - accuracy: 0.8671 - loss: 0.3185 - val_accuracy: 0.8449 - val_loss: 0.3629
# Epoch 2/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8839 - loss: 0.2959
# Epoch 2: val_loss did not improve from 0.34000
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1334s 9s/step - accuracy: 0.8839 - loss: 0.2959 - val_accuracy: 0.8494 - val_loss: 0.3407
# Epoch 3/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8787 - loss: 0.2926
# Epoch 3: val_loss did not improve from 0.34000
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1331s 9s/step - accuracy: 0.8787 - loss: 0.2926 - val_accuracy: 0.8383 - val_loss: 0.3563
# Epoch 4/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8799 - loss: 0.2979
# Epoch 4: val_loss did not improve from 0.34000
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1324s 9s/step - accuracy: 0.8799 - loss: 0.2978 - val_accuracy: 0.8507 - val_loss: 0.3621
# Epoch 5/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8855 - loss: 0.2721
# Epoch 5: val_loss did not improve from 0.34000
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1377s 10s/step - accuracy: 0.8855 - loss: 0.2721 - val_accuracy: 0.8481 - val_loss: 0.3718
# Epoch 6/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8936 - loss: 0.2674
# Epoch 6: val_loss improved from 0.34000 to 0.33646, saving model to /kaggle/working/best_weights.weights.h5
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1326s 9s/step - accuracy: 0.8936 - loss: 0.2674 - val_accuracy: 0.8488 - val_loss: 0.3365
# Epoch 7/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8848 - loss: 0.2733
# Epoch 7: val_loss did not improve from 0.33646
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1323s 9s/step - accuracy: 0.8848 - loss: 0.2732 - val_accuracy: 0.8435 - val_loss: 0.3639
# Epoch 8/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8847 - loss: 0.2716
# Epoch 8: val_loss did not improve from 0.33646
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1331s 9s/step - accuracy: 0.8848 - loss: 0.2715 - val_accuracy: 0.8514 - val_loss: 0.3520
# Epoch 9/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.9027 - loss: 0.2452
# Epoch 9: val_loss did not improve from 0.33646
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1330s 9s/step - accuracy: 0.9027 - loss: 0.2452 - val_accuracy: 0.8533 - val_loss: 0.3502
# Epoch 10/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.9000 - loss: 0.2569
# Epoch 10: val_loss did not improve from 0.33646
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1319s 9s/step - accuracy: 0.9000 - loss: 0.2568 - val_accuracy: 0.8462 - val_loss: 0.3563
# Epoch 11/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.9132 - loss: 0.2288
# Epoch 11: val_loss did not improve from 0.33646
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1319s 9s/step - accuracy: 0.9132 - loss: 0.2288 - val_accuracy: 0.8527 - val_loss: 0.3486
# Epoch 12/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.9210 - loss: 0.2095
# Epoch 12: val_loss did not improve from 0.33646
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1379s 10s/step - accuracy: 0.9210 - loss: 0.2095 - val_accuracy: 0.8468 - val_loss: 0.3518
# Epoch 13/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.9241 - loss: 0.2100
# Epoch 13: val_loss did not improve from 0.33646
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1328s 9s/step - accuracy: 0.9240 - loss: 0.2100 - val_accuracy: 0.8494 - val_loss: 0.3700
# Epoch 14/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.9206 - loss: 0.2128
# Epoch 14: val_loss did not improve from 0.33646
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1327s 9s/step - accuracy: 0.9206 - loss: 0.2128 - val_accuracy: 0.8416 - val_loss: 0.3757
# Epoch 15/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8683 - loss: 0.3151
# Epoch 15: val_loss did not improve from 0.33646
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1327s 9s/step - accuracy: 0.8683 - loss: 0.3151 - val_accuracy: 0.8403 - val_loss: 0.3741
# Epoch 16/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8811 - loss: 0.2906
# Epoch 16: val_loss did not improve from 0.33646
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1380s 10s/step - accuracy: 0.8811 - loss: 0.2907 - val_accuracy: 0.8572 - val_loss: 0.3516
# Epoch 17/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8753 - loss: 0.3019
# Epoch 17: val_loss did not improve from 0.33646
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1314s 9s/step - accuracy: 0.8753 - loss: 0.3019 - val_accuracy: 0.8390 - val_loss: 0.3587
# Epoch 18/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8830 - loss: 0.2928
# Epoch 18: val_loss did not improve from 0.33646
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1319s 9s/step - accuracy: 0.8830 - loss: 0.2928 - val_accuracy: 0.8572 - val_loss: 0.3414
# Epoch 19/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8650 - loss: 0.3100
# Epoch 19: val_loss did not improve from 0.33646
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1340s 9s/step - accuracy: 0.8650 - loss: 0.3100 - val_accuracy: 0.8527 - val_loss: 0.3449
# Epoch 20/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8636 - loss: 0.3107
# Epoch 20: val_loss improved from 0.33646 to 0.33379, saving model to /kaggle/working/best_weights.weights.h5
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1377s 10s/step - accuracy: 0.8636 - loss: 0.3107 - val_accuracy: 0.8527 - val_loss: 0.3338
# Epoch 21/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8716 - loss: 0.3051
# Epoch 21: val_loss did not improve from 0.33379
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1312s 9s/step - accuracy: 0.8716 - loss: 0.3051 - val_accuracy: 0.8442 - val_loss: 0.3543
# Epoch 22/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8844 - loss: 0.2867
# Epoch 22: val_loss did not improve from 0.33379
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1313s 9s/step - accuracy: 0.8843 - loss: 0.2868 - val_accuracy: 0.8546 - val_loss: 0.3387
# Epoch 23/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8783 - loss: 0.2888
# Epoch 23: val_loss did not improve from 0.33379
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1320s 9s/step - accuracy: 0.8783 - loss: 0.2888 - val_accuracy: 0.8507 - val_loss: 0.3421
# Epoch 24/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8741 - loss: 0.3048
# Epoch 24: val_loss did not improve from 0.33379
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1317s 9s/step - accuracy: 0.8742 - loss: 0.3048 - val_accuracy: 0.8520 - val_loss: 0.3475
# Epoch 25/25
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8688 - loss: 0.2969
# Epoch 25: val_loss did not improve from 0.33379
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1314s 9s/step - accuracy: 0.8688 - loss: 0.2969 - val_accuracy: 0.8553 - val_loss: 0.3385
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 327s 7s/step - accuracy: 0.8083 - loss: 0.4636
# Test Accuracy Before Fine-tuning: 84.71%

# %%
train_loss = history.history['loss']
val_loss   = history.history['val_loss']
train_acc = history.history['accuracy']
val_acc   = history.history['val_accuracy']
epochs_range = range(len(train_loss))

# Plot Training & Validation Loss
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, train_loss, label='Training Loss', color="black")
plt.plot(epochs_range, val_loss, label='Validation Loss', color="red", linestyle="--")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

# Plot Training & Validation Accuracy
plt.subplot(1, 2, 2)
plt.plot(epochs_range, train_acc, label='Training Accuracy', color="black")
plt.plot(epochs_range, val_acc, label='Validation Accuracy', color="red", linestyle="--")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.show()

# %%
true_labels = validation_generator.classes  # Actual labels from the dataset

pred_probs  = model.predict(validation_generator)  # Probabilities
pred_labels = np.argmax(pred_probs, axis=1)  # Convert softmax to class indices

# Step 3: Compute confusion matrix
cm = confusion_matrix(true_labels, pred_labels)

# Step 4: Plot the confusion matrix
plt.figure(figsize=(8,6))
sea.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=validation_generator.class_indices.keys(), yticklabels=validation_generator.class_indices.keys())
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 341s 7s/step
